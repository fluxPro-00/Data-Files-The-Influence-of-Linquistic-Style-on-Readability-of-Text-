# %%
import pandas as pd

df = pd.read_excel("Concreteness_ratings_Brysbaert_et_al_BRM.xlsx")

df
# Out:
#                   Word  Bigram  Conc.M  Conc.SD  Unknown  Total  \
# 0          roadsweeper       0    4.85     0.37        1     27
# 1          traindriver       0    4.54     0.71        3     29
# 2                 tush       0    4.45     1.01        3     25
# 3            hairdress       0    3.93     1.28        0     29
# 4        pharmaceutics       0    3.77     1.41        4     26
# ...                ...     ...     ...      ...      ...    ...
# 39949         unenvied       0    1.21     0.62        1     30
# 39950     agnostically       0    1.20     0.50        2     27
# 39951  conceptualistic       0    1.18     0.50        4     26
# 39952  conventionalism       0    1.18     0.48        1     29
# 39953    essentialness       0    1.04     0.20        2     26
#
#        Percent_known  SUBTLEX Dom_Pos
# 0           0.962963        0       0
# 1           0.896552        0       0
# 2           0.880000       66       0
# 3           1.000000        1       0
# ...

# %%
min_value = df["Conc.M"].min()
max_value = df["Conc.M"].max()

print(f"Minimum Conc.M: {min_value}")
print(f"Maximum Conc.M: {max_value}")
# Out:
# Minimum Conc.M: 1.04
# Maximum Conc.M: 5.0

# %%
columns_to_drop = ["Bigram", "Unknown", "Total", "Percent_known", "SUBTLEX", "Dom_Pos"]
df = df.drop(columns=columns_to_drop)
df
# Out:
#                   Word  Conc.M  Conc.SD
# 0          roadsweeper    4.85     0.37
# 1          traindriver    4.54     0.71
# 2                 tush    4.45     1.01
# 3            hairdress    3.93     1.28
# 4        pharmaceutics    3.77     1.41
# ...                ...     ...      ...
# 39949         unenvied    1.21     0.62
# 39950     agnostically    1.20     0.50
# 39951  conceptualistic    1.18     0.50
# 39952  conventionalism    1.18     0.48
# 39953    essentialness    1.04     0.20
#
# [39954 rows x 3 columns]

# %%
df["Category"] = df["Conc.M"].apply(lambda x: "Concrete" if x >= 3 else "Abstract")

print(df.head())
# Out:
#             Word  Bigram  Conc.M  Conc.SD  Unknown  Total  Percent_known  \
# 0    roadsweeper       0    4.85     0.37        1     27       0.962963
# 1    traindriver       0    4.54     0.71        3     29       0.896552
# 2           tush       0    4.45     1.01        3     25       0.880000
# 3      hairdress       0    3.93     1.28        0     29       1.000000
# 4  pharmaceutics       0    3.77     1.41        4     26       0.846154
#
#    SUBTLEX Dom_Pos  Category
# 0        0       0  Concrete
# 1        0       0  Concrete
# 2       66       0  Concrete
# 3        1       0  Concrete
# 4        0       0  Concrete

# %%
df.to_csv("categorized_words.csv", index=False, encoding="utf-8")
